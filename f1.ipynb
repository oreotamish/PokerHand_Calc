# %%
import pandas_datareader.data as web
import numpy as np
import  pandas as pd
import matplotlib.pyplot as plt

# %%
start = "2021-05-08"
end = "2022-05-11"
data = web.DataReader("TSLA", "yahoo", start, end)
nissan = web.DataReader("NSANY", 'yahoo',start, end)
bmw = web.DataReader("BMW.DE", 'yahoo',start, end)
mercedes = web.DataReader("DAI.DE", 'yahoo',start, end)
ford = web.DataReader("F", 'yahoo',start, end)
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2021-05-07  230.000000  220.073334  221.933334  224.123337   70407600
# 2021-05-10  221.683334  209.203339  221.633331  209.679993   94177200
# 2021-05-11  209.033340  198.533340  199.746674  205.733337  139511700
# 2021-05-12  206.803329  195.589996  200.830002  196.630005  101470800
# 2021-05-13  202.153336  186.550003  200.513336  190.563339  132554700
# ...                ...         ...         ...         ...        ...
# 2022-05-05  315.200012  285.899994  313.006653  291.093323   92519100
# 2022-05-06  296.000000  281.036682  295.666656  288.549988   72903000
# 2022-05-09  281.876678  260.383331  278.816681  262.369995   90810300
# 2022-05-10  275.119995  258.083344  273.103333  266.679993   84401700
# 2022-05-11  269.923340  242.399994  265.000000  244.666672   97224600
#
#              Adj Close
# Date
# 2021-05-07  224.123337
# 2021-05-10  209.679993
# 2021-05-11  205.733337
# ...

# %%
data.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2021-05-07  230.000000  220.073334  221.933334  224.123337   70407600
# 2021-05-10  221.683334  209.203339  221.633331  209.679993   94177200
# 2021-05-11  209.033340  198.533340  199.746674  205.733337  139511700
# 2021-05-12  206.803329  195.589996  200.830002  196.630005  101470800
# 2021-05-13  202.153336  186.550003  200.513336  190.563339  132554700
#
#              Adj Close
# Date
# 2021-05-07  224.123337
# 2021-05-10  209.679993
# 2021-05-11  205.733337
# 2021-05-12  196.630005
# 2021-05-13  190.563339

# %%
data.tail()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2022-05-05  315.200012  285.899994  313.006653  291.093323  92519100
# 2022-05-06  296.000000  281.036682  295.666656  288.549988  72903000
# 2022-05-09  281.876678  260.383331  278.816681  262.369995  90810300
# 2022-05-10  275.119995  258.083344  273.103333  266.679993  84401700
# 2022-05-11  269.923340  242.399994  265.000000  244.666672  97224600
#
#              Adj Close
# Date
# 2022-05-05  291.093323
# 2022-05-06  288.549988
# 2022-05-09  262.369995
# 2022-05-10  266.679993
# 2022-05-11  244.666672

# %%
data['Close'].plot(title="Stocks at Closing", figsize = (16,5))
data['Open'].plot(label = "Stock prices at open")
data['High'].plot(label = "Stock prices on a high")
data['Low'].plot(label = "Stock prices on a low")
plt.legend()
plt.title("TESLA stocks prices")
plt.ylabel("Stock Prices")
plt.show()
